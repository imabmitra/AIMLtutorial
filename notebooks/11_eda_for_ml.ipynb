# %% [markdown]
# # Notebook 11: EDA for Machine Learning

# %% [markdown]
# EDA focused on feature quality, distributions, and feature–target relationships.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv")
df = df[['age','fare','sex','embarked','survived']]

# %%
df['survived'].value_counts(normalize=True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df[['age','fare']].hist(bins=30, figsize=(10,4))
plt.show()

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby('embarked')['survived'].mean()
# Out:
# embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: survived, dtype: float64

# %%
df[['age','fare','survived']].corr()
# Out:
#                age      fare  survived
# age       1.000000  0.096067 -0.077221
# fare      0.096067  1.000000  0.257307
# survived -0.077221  0.257307  1.000000
